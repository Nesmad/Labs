# %%
from stackapi import StackAPI

# %%
SITE = StackAPI('stackoverflow')
questions = SITE.fetch('questions', fromdate=1636282963, todate=1638874963)
questions
answers = SITE.fetch('answers', fromdate=1636282963, todate=1638874963)
answers
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 232,
#  'total': 0,
#  'items': [{'owner': {'reputation': 858,
#     'user_id': 15208373,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/xLxmO.png?s=256&g=1',
#     'display_name': 'bel3atar',
#     'link': 'https://stackoverflow.com/users/15208373/bel3atar'},
#    'is_accepted': False,
#    'score': 2,
#    'last_activity_date': 1638877201,
#    'last_edit_date': 1638877201,
#    'creation_date': 1638539731,
#    'answer_id': 70215462,
#    'question_id': 70215277,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 4980,
#     'user_id': 13972333,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/oTBMs.png?s=256&g=1',
#     'display_name': 'GuedesBF',
#     'link': 'https://stackoverflow.com/users/13972333/guedesbf'},
#    'is_accepted': False,
#    'score': 2,
#    'last_activity_date': 1638877193,
# ...

# %%
SITE = StackAPI('stackoverflow')
questions = SITE.fetch('questions', fromdate=1636282963, todate=1638874963, min=5 ,tagged='python', sort='votes')
questions
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 256,
#  'total': 0,
#  'items': [{'tags': ['python', 'list', 'caching'],
#    'owner': {'reputation': 1224,
#     'user_id': 5785250,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/Ak0LE.jpg?s=256&g=1',
#     'display_name': 'fdireito',
#     'link': 'https://stackoverflow.com/users/5785250/fdireito'},
#    'is_answered': True,
#    'view_count': 5708,
#    'accepted_answer_id': 69950093,
#    'answer_count': 3,
#    'score': 71,
#    'last_activity_date': 1638423260,
#    'creation_date': 1636758794,
#    'last_edit_date': 1636851502,
#    'question_id': 69950010,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69950010/why-is-python-list-slower-when-sorted',
#    'title': 'Why is Python list slower when sorted?'},
#   {'tags': ['python'],
#    'owner': {'reputation': 219,
#     'user_id': 16372049,
# ...

# %%
from stackapi import StackAPI
SITE = StackAPI('stackoverflow')
badges = SITE.fetch('badges', ids=[6784, 6473])
badges
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 270,
#  'total': 0,
#  'items': [{'badge_type': 'tag_based',
#    'award_count': 1,
#    'rank': 'silver',
#    'badge_id': 6784,
#    'link': 'https://stackoverflow.com/badges/6784/asterisk',
#    'name': 'asterisk'},
#   {'badge_type': 'tag_based',
#    'award_count': 1,
#    'rank': 'gold',
#    'badge_id': 6473,
#    'link': 'https://stackoverflow.com/badges/6473/sql-server-2012',
#    'name': 'sql-server-2012'}]}

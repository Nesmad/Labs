# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import matplotlib.pyplot as plt
import math
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2
#print(x)
#print(y)

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
plt.plot(x,y,label='linear')
plt.plot(x,z,label='quadratic')
plt.xlabel('x')
plt.ylabel('result')
plt.title('linear vs quadratic')
plt.legend()
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
fig,[ax1,ax2] = plt.subplots(1,2)

ax1.plot(x,y)
ax1.set_title('linear plot')
ax1.set_xlabel('x label')
ax1.set_ylabel('y label')

ax2.plot(x,z)
ax2.set_title('quadratic plot')
ax2.set_xlabel('x label')
ax2.set_ylabel('z label')

plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here

fig,[ax1,ax2] = plt.subplots(1,2,figsize=(10,5))
fig.subplots_adjust(bottom=0.15, left=0.01)

ax1.plot(x,y)
ax1.set_title('linear plot',fontsize=16,fontweight='bold')
ax1.set_xlabel('x label', fontsize=12)
ax1.set_ylabel('y label', fontsize=12)

ax2.plot(x,z)
ax2.set_title('quadratic plot',fontsize=16,fontweight='bold')
ax2.set_xlabel('x label', fontsize=12)
ax2.set_ylabel('z label', fontsize=12)

plt.show()

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here

fig,[ax1,ax2] = plt.subplots(1,2)
ax2.set_yscale('log')

ax1.plot(x,z)
ax1.set_title('quadratic')
ax1.set_xlabel('x label')
ax1.set_ylabel('quadratic label')

ax2.plot(x,y2)
ax2.set_title('expotential')
ax2.set_xlabel('x label')
ax2.set_ylabel('explotential label')

plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here
fig,[ax1,ax2] = plt.subplots(1,2)

ax1.set_yscale('log')
ax2.set_yscale('log')

ax1.plot(x,z,label='q_legend')
ax1.set_title('quadratic')
ax1.set_xlabel('x label')
ax1.set_ylabel('quadratic label')

ax2.plot(x,y2,label='e_legend')
ax2.set_title('expotential')
ax2.set_xlabel('x label')
ax2.set_ylabel('explotential label')

ax1.legend()
ax2.legend()

plt.show()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit = pd.read_csv('/Users/carrie/IronHack/DAFT_NOV_21_01/module_2/Lab_1_Matplotlib_and_Seaborn/Fitbit2.csv')
fitbit
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  2016-05-03            3796  18588     14.13      16            599.000
# 363  2016-05-04            3525  16382     12.39      16            684.000
# 364  2016-05-05            3649  21913     16.40      19            701.000
# 365  2016-05-06            3539  19023     14.79      15            575.000
# 366  2016-05-07             304   9526      7.08       2            564.000
#
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
#Method 1: using plot.bar

month_med = fitbit[["Months_encoded", "Steps"]].groupby(["Months_encoded"]).agg("median")
p1 = month_med.plot.bar(figsize=(12,4))

plt.savefig('/Users/carrie/IronHack/IronZijing/Module_2/Lab_1_Matplotlib_and_Seaborn/Figures/MEDIAN STEPS BY MONTH_ENCODED.png')


week_med = fitbit[["Work_or_Weekend", "Steps"]].groupby(["Work_or_Weekend"]).agg("median")
p2 = week_med.plot.bar(figsize=(12,4))

plt.savefig('/Users/carrie/IronHack/IronZijing/Module_2/Lab_1_Matplotlib_and_Seaborn/Figures/MEDIAN STEPS BY WORK_OR_WEEKEND.png')

# %%
#Method 2: using subplots

fig,[p1,p2] = plt.subplots(1,2,figsize=(12,4))

# MEDIAN STEPS BY MONTH_ENCODED
# your code here
m_s = fitbit.groupby('Months_encoded')[['Months_encoded','Steps']].median()

p1.scatter(m_s['Months_encoded'], m_s['Steps'])
p1.set_title('MEDIAN STEPS BY MONTH_ENCODED')
p1.set_xlabel('Months_encoded')
p1.set_ylabel('Steps')

# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here

w_s = fitbit.groupby('Work_or_Weekend')[['Work_or_Weekend','Steps']].median()
w_s
p2.scatter(w_s['Work_or_Weekend'], w_s['Steps'])
p2.set_title('MEDIAN STEPS BY WORK_OR_WEEKEND')
p2.set_xlabel('Work_or_Weekend')
p2.set_ylabel('Steps')
plt.show()

fig.savefig('/Users/carrie/IronHack/IronZijing/Module_2/Lab_1_Matplotlib_and_Seaborn/Figures/MEDIAN STEPS scatter.png')

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here
m_list = ['Minutes Lightly Active','Minutes Very Active','Minutes Sedentary']
for m in m_list:
    fitbit.sort_values(by=[m, "Steps"], inplace=True)
    fitbit.plot.scatter(x=m, y=["Steps"])

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic = pd.read_csv('/Users/carrie/IronHack/DAFT_NOV_21_01/module_2/Lab_1_Matplotlib_and_Seaborn/titanic.csv')
#print(titanic.isnull().sum())
titanic
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name  Gender        Age  \
# 0                               Braund, Mr. Owen Harris    male  22.000000
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                                Heikkinen, Miss. Laina  female  26.000000
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                              Allen, Mr. William Henry    male  35.000000
# ...

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
num_cols = titanic.select_dtypes(['int64','float64']).columns
num_cols
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
# CATEGORICAL VARIABLES
# your code here
cate_cols = titanic.select_dtypes(['object']).columns
cate_cols
# Out:
# Index(['Name', 'Gender', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
import matplotlib.style
import matplotlib as mpl
mpl.style.use('classic')
mpl.rcParams['figure.figsize'] = [12, 6]

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
titanic.plot.scatter(x="Age",y='PassengerId')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='PassengerId'>

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
fig,[ax1,ax2,ax3] = plt.subplots(1,3)
fig.subplots_adjust(bottom=0.15, left=0.0001)

ax1.hist(titanic['Age'], bins=10)
ax1.set_title('Age in 10 bins')
ax1.set_xlabel('Age')
ax1.set_ylabel('No. of people')

ax2.hist(titanic['Age'], bins=20)
ax2.set_title('Age in 20 bins')
ax2.set_xlabel('Age')
ax2.set_ylabel('No. of people')

ax3.hist(titanic['Age'], bins=50)
ax3.set_title('Age in 50 bins')
ax3.set_xlabel('Age')
ax3.set_ylabel('No. of people')

plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here
The larger the bin sizes, the fewer bins there will be to cover the whole range of data. 
With a smaller bin size, the more bins there will need to be. 
"""
# Out:
# '\nyour comments here\nThe larger the bin sizes, the fewer bins there will be to cover the whole range of data. \nWith a smaller bin size, the more bins there will need to be. \n'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
sns.lmplot(x='Age', y='PassengerId', data=titanic, fit_reg=False)

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
g_count = titanic[["Gender", "PassengerId"]].groupby(["Gender"]).agg("count")
g_count.plot.bar(legend=False)
     
plt.ylabel('No. of people')
# Out:
# Text(0, 0.5, 'No. of people')

# %%
# Method 2 - seaborn
# your code here
sns.countplot(x="Gender", data=titanic, palette = 'pastel')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
sns.countplot(x="Pclass", data=titanic)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
sns.distplot(titanic['Age'])
# Out:
# /Users/carrie/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
"""
your comments here
to clearly see the age distribution & gender statistically 
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
50%+ of the people on titanic are in the age range of 20-40 years old
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
sns.boxplot(x = titanic['Gender'], y = titanic['Age'])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Age'>

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
there are very old people on titanic too, but quite few
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
plt.plot(titanic.Age,titanic.Fare,label='linear')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('linear?')
t_f = titanic.sort_values(by=['Age', 'Fare'], inplace=True)
plt.legend()
plt.show()

# %%
# Method 2 - seaborn
# your code here
sns.lineplot(x=titanic.Age,y=titanic.Fare)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
sns.heatmap(titanic.corr(), annot = True, cmap = 'YlGnBu')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
Fare & Pclass with correlation at -0.56
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
sns.violinplot(x = titanic['Pclass'], y = titanic['Age'])
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
sns.violinplot(x = titanic['Gender'], y = titanic['Age'])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Age'>
